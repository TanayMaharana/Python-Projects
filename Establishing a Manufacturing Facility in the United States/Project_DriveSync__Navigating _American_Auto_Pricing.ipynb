# %% [markdown]
# # **INTRODUCTION**
# #### In this ambitious Capstone project, we explore the American auto market, analyzing pricing factors using data and advanced tools to uncover hidden insights for XYZ Motors' success.
# ### Libraries To Be Used:
# - #### Pandas
# - #### Numpy

# %% [markdown]
#                              Task 1: Loading and Initial Data Exploration:

# %%
## Importing the libraries
import pandas as pd 
import numpy as np 

# Loading the data
df_unclean = pd.read_csv(r"C:\Users\TANAY_MAHARANA\Documents\Python scripts\csv,text etc files for practice\car-prices_unclean - car-prices_unclean.csv.csv")
print(df_unclean["price"].median())
print("First Few Rows of the Dataset:\n",df_unclean.head())  ## printing the initial 5rows            
print()
print("Dimensions of the Dataset:\n",df_unclean.shape)  ## checking dataset dimensions                 
print()
print("Summary of the Dataset:")  
print(df_unclean.info()) ## checking the summary of the dataset          
print()
print("Missing Values in the Dataset:\n",df_unclean.isnull().sum())  ## checking for null values in the dataset
print()
print("Duplicate values in the dataset:\n",df_unclean.duplicated().sum())  ## checking for duplicate value sin the data
print()
print("Unique values in each column:\n",df_unclean.nunique())  ## checking for unique values in each column 
print()
print("Summary Statistics for Numerical Columns:\n",df_unclean.describe())  ## checking summary statistics for numerical columns

# %% [markdown]
#                              Task 02: Handling Missing values and Outliers:

# %%
df_clean = df_unclean.copy()  ## making a deep copy to work on

df_clean.drop(["car_ID", "Untitled"], axis = 1, inplace=True)  ## dropping unnecessary columns

symboling_mask = np.mean(df_clean["symboling"])  ## creating a mask value to fill null
df_clean["symboling"].fillna(symboling_mask, inplace=True)  ## filling nulls

price_mask = df_clean["price"].median()
df_clean["price"].fillna(price_mask, inplace=True)

fueltype_mask = df_clean["fueltype"].mode()[0]
df_clean["fueltype"].fillna(fueltype_mask, inplace=True)


# print(df_clean.isnull().sum())  ## confirming all non-null columns

## Identifying outliers in the price column 
Q1 = np.percentile(df_clean["price"], 25)
Q3 = np.percentile(df_clean["price"], 75)

IQR = Q3 - Q1  ## interquartile range

lower_whisker = Q1 - 1.5*(IQR)  ## lower bound

upper_whisker = Q3 + 1.5*(IQR)  ## upper bound

outliers = df_clean[(df_clean["price"] < lower_whisker) | (df_clean["price"] > upper_whisker)]  ## conditional formatting
price_outlier_count = outliers["price"].count()

print(f"Possible outliers in the price column are:\n{outliers}")

df_clean["price"] = np.log1p(df_clean["price"])  ## normalizing the extreme prizes
# Out:
# Possible outliers in the price column are:
#      Unnamed: 0  symboling                   CarName fueltype aspiration  \
# 15           15   0.000000                    bmw x4      gas        std
# 16           16   0.000000                    bmw x5      gas        std
# 17           17   0.000000                    bmw x3      gas        std
# 47           47   0.000000                 jaguar xj      gas        std
# 48           48   0.000000                 jaguar xf      gas        std
# 67           67  -1.000000  buick electra 225 custom   diesel      turbo
# 68           68  -1.000000  buick century luxus (sw)   diesel      turbo
# 69           69   0.841463             buick century   diesel      turbo
# 70           70  -1.000000             buick skyhawk   diesel      turbo
# 71           71  -1.000000   buick opel isuzu deluxe      gas        std
# 72           72   3.000000             buick skylark      gas        std
# 73           73   0.841463     buick century special      gas        std
# 126         126   3.000000         porcshce panamera      gas        std
# 127         127   3.000000           porsche cayenne      gas        std
# 128         128   3.000000            porsche boxter      gas        std
# 129         129   1.000000           porsche cayenne      gas        std
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 15        four        sedan        rwd          front      103.5  ...
# 16         two        sedan        rwd          front      103.5  ...
# 17        four        sedan        rwd          front      110.0  ...
# 47        four        sedan        rwd          front      113.0  ...
# 48        four        sedan        rwd          front      113.0  ...
# 67        four        sedan        rwd          front      110.0  ...
# 68        four        wagon        rwd          front      110.0  ...
# 69         two      hardtop        rwd          front      106.7  ...
# 70        four        sedan        rwd          front      115.6  ...
# 71        four        sedan        rwd          front      115.6  ...
# 72         two  convertible        rwd          front       96.6  ...
# 73        four        sedan        rwd          front      120.9  ...
# 126        two      hardtop        rwd           rear       89.5  ...
# 127        two      hardtop        rwd           rear       89.5  ...
# 128        two  convertible        rwd           rear       89.5  ...
# 129        two    hatchback        rwd          front       98.4  ...
#
#      enginesize  fuelsystem  boreratio  stroke compressionratio horsepower  \
# 15          209        mpfi       3.62    3.39              8.0        182
# 16          209        mpfi       3.62    3.39              8.0        182
# 17          209        mpfi       3.62    3.39              8.0        182
# 47          258        mpfi       3.63    4.17              8.1        176
# 48          258        mpfi       3.63    4.17              8.1        176
# 67          183         idi       3.58    3.64             21.5        123
# 68          183         idi       3.58    3.64             21.5        123
# 69          183         idi       3.58    3.64             21.5        123
# 70          183         idi       3.58    3.64             21.5        123
# 71          234        mpfi       3.46    3.10              8.3        155
# 72          234        mpfi       3.46    3.10              8.3        155
# 73          308        mpfi       3.80    3.35              8.0        184
# 126         194        mpfi       3.74    2.90              9.5        207
# 127         194        mpfi       3.74    2.90              9.5        207
# 128         194        mpfi       3.74    2.90              9.5        207
# 129         203        mpfi       3.94    3.11             10.0        288
#
#      peakrpm citympg  highwaympg    price
# 15      5400      16          22  30760.0
# 16      5400      16          22  41315.0
# 17      5400      15          20  36880.0
# 47      4750      15          19  32250.0
# 48      4750      15          19  35550.0
# 67      4350      22          25  25552.0
# 68      4350      22          25  28248.0
# 69      4350      22          25  28176.0
# 70      4350      22          25  31600.0
# 71      4750      16          18  34184.0
# 72      4750      16          18  35056.0
# 73      4500      14          16  40960.0
# 126     5900      17          25  32528.0
# 127     5900      17          25  34028.0
# 128     5900      17          25  37028.0
# 129     5750      17          28  31400.5
#
# [16 rows x 26 columns]

# %% [markdown]
#                              Task 03: Data Cleaning and Preparation:

# %%
# print(df_clean.head(25))  ## checking the carname column 

car_companies = pd.Series([car.split(" ")[0] for car in df_clean['CarName']], index = df_clean.index)

# df_clean.drop(columns= ['CarName'], axis = 1, inplace = True)

df_clean["car_company"] = car_companies  ## adding new column 'car_company'

## fixing some typos
df_clean["car_company"].replace({"vokswagen":"volkswagen", "toyouta":"toyota", "maxda":"mazda", "vw":"volkswagen", "porcshce": "porsche"}, inplace=True)

## counting the number of cars by each company
df_clean_company_pivot = df_clean.pivot_table(values="CarName", index="car_company", aggfunc="count").sort_values("CarName", ascending=False)
print(df_clean_company_pivot)
# Out:
#              CarName
# car_company
# toyota            32
# nissan            17
# mazda             17
# mitsubishi        13
# honda             13
# volkswagen        12
# subaru            12
# peugeot           11
# volvo             11
# dodge              9
# buick              8
# bmw                8
# audi               7
# plymouth           7
# saab               6
# porsche            5
# isuzu              4
# jaguar             3
# alfa-romero        3
# chevrolet          3
# renault            2
# Nissan             1
# mercury            1

# %% [markdown]
#                              Task 04: Identifying Numerical Factors Impacting Car Prices

# %%
numerical_columns = df_clean.select_dtypes(np.number)   ## extracting numerical columns 
correlation = numerical_columns.corr()                  ## finding correlation between numerical columns 

price_correlations = correlation["price"]               ## picking the subset,co-relation of price with other numerical columns 

## these are the correlation of other numerical columns with 'price'
print(f"Correlation coefficients with 'price':\n{price_correlations}")

print()

## these are the factors that have (absolute value of correlation > 0.4) have significant impact on car prices
significant_factors = price_correlations[np.abs(price_correlations) > 0.4]

print(f"Factors with significant impact on car prices:\n{significant_factors}")
# Out:
# Correlation coefficients with 'price':
# Unnamed: 0         -0.085602
# symboling          -0.022127
# wheelbase           0.553529
# carlength           0.683837
# carwidth            0.702964
# carheight           0.158797
# curbweight          0.785020
# enginesize          0.708287
# boreratio           0.515868
# stroke              0.116368
# compressionratio    0.079953
# horsepower          0.718771
# peakrpm            -0.081336
# citympg            -0.681929
# highwaympg         -0.675603
# price               1.000000
# Name: price, dtype: float64
#
# Factors with significant impact on car prices:
# wheelbase     0.553529
# carlength     0.683837
# carwidth      0.702964
# curbweight    0.785020
# enginesize    0.708287
# boreratio     0.515868
# horsepower    0.718771
# citympg      -0.681929
# highwaympg   -0.675603
# price         1.000000
# Name: price, dtype: float64

# %% [markdown]
#                              Task 05: Identifying Categorical Factors Impacting Car Prices

# %%
categorical_columns = df_clean.select_dtypes("object", "category")
unique_fueltypes = categorical_columns['fueltype'].unique()

for type in unique_fueltypes:
    print(type)
    subset = df_clean[df_clean["fueltype"] == type]
    price_description = subset["price"].describe()
    print(price_description)
# Out:
# gas
# count    191.000000
# mean       9.337526
# std        0.441184
# min        8.540714
# 25%        9.067428
# 50%        9.287209
# 75%        9.539529
# max       10.629005
# Name: price, dtype: float64
# diesel
# count    14.000000
# mean      9.640715
# std       0.541325
# min       8.867850
# 25%       9.061825
# 50%       9.765265
# 75%      10.116378
# max      10.360944
# Name: price, dtype: float64

# %%
categorical_columns = df_clean.select_dtypes("object", "category")
# print(categorical_columns)

for column in categorical_columns.columns:
    unique_values = categorical_columns[column].unique()
    print(f"Impact of {column} on 'price':")

    for value in unique_values:
        subset = df_clean[df_clean[column] == value]
        price_description = subset["price"].describe()
        print(f"Category: {value}")
        print(price_description)
    print("\n")
# Out:
# Impact of CarName on 'price':
# Category: alfa-romero giulia
# count    1.000000
# mean     9.510149
# std           NaN
# min      9.510149
# 25%      9.510149
# 50%      9.510149
# 75%      9.510149
# max      9.510149
# Name: price, dtype: float64
# Category: alfa-romero stelvio
# count    1.000000
# mean     9.711176
# std           NaN
# min      9.711176
# 25%      9.711176
# 50%      9.711176
# 75%      9.711176
# max      9.711176
# Name: price, dtype: float64
# Category: alfa-romero Quadrifoglio
# count    1.000000
# mean     9.711176
# std           NaN
# min      9.711176
# 25%      9.711176
# 50%      9.711176
# 75%      9.711176
# max      9.711176
# Name: price, dtype: float64
# Category: audi 100 ls
# count    1.000000
# mean     9.543306
# std           NaN
# min      9.543306
# 25%      9.543306
# 50%      9.543306
# 75%      9.543306
# max      9.543306
# Name: price, dtype: float64
# Category: audi 100ls
# count    2.000000
# mean     9.774547
# std      0.010457
# min      9.767152
# 25%      9.770849
# 50%      9.774547
# 75%      9.778244
# max      9.781941
# Name: price, dtype: float64
# Category: audi fox
# count    1.0000
# mean     9.6324
# std         NaN
# min      9.6324
# 25%      9.6324
# 50%      9.6324
# 75%      9.6324
# max      9.6324
# Name: price, dtype: float64
# Category: audi 5000
# count    1.000000
# mean     9.848028
# std           NaN
# min      9.848028
# 25%      9.848028
# 50%      9.848028
# 75%      9.848028
# max      9.848028
# Name: price, dtype: float64
# Category: audi 4000
# count     1.000000
# mean     10.080629
# std            NaN
# min      10.080629
# 25%      10.080629
# 50%      10.080629
# 75%      10.080629
# max      10.080629
# Name: price, dtype: float64
# Category: audi 5000s (diesel)
# count    1.000000
# mean     9.790328
# std           NaN
# min      9.790328
# 25%      9.790328
# 50%      9.790328
# 75%      9.790328
# max      9.790328
# Name: price, dtype: float64
# Category: bmw 320i
# count    2.000000
# mean     9.721766
# std      0.020988
# min      9.706925
# 25%      9.714345
# 50%      9.721766
# 75%      9.729186
# max      9.736606
# Name: price, dtype: float64
# Category: bmw x1
# count    1.000000
# mean     9.950896
# std           NaN
# min      9.950896
# 25%      9.950896
# 50%      9.950896
# 75%      9.950896
# max      9.950896
# Name: price, dtype: float64
# Category: bmw x3
# count     2.000000
# mean     10.236382
# std       0.394664
# min       9.957313
# 25%      10.096847
# 50%      10.236382
# 75%      10.375917
# max      10.515452
# Name: price, dtype: float64
# Category: bmw z4
# count     1.000000
# mean     10.109119
# std            NaN
# min      10.109119
# 25%      10.109119
# 50%      10.109119
# 75%      10.109119
# max      10.109119
# Name: price, dtype: float64
# Category: bmw x4
# count     1.000000
# mean     10.334003
# std            NaN
# min      10.334003
# 25%      10.334003
# 50%      10.334003
# 75%      10.334003
# max      10.334003
# Name: price, dtype: float64
# Category: bmw x5
# count     1.000000
# mean     10.629005
# std            NaN
# min      10.629005
# 25%      10.629005
# 50%      10.629005
# 75%      10.629005
# max      10.629005
# Name: price, dtype: float64
# Category: chevrolet impala
# count    1.00000
# mean     8.54714
# std          NaN
# min      8.54714
# 25%      8.54714
# 50%      8.54714
# 75%      8.54714
# max      8.54714
# Name: price, dtype: float64
# Category: chevrolet monte carlo
# count    1.00000
# mean     8.74767
# std          NaN
# min      8.74767
# 25%      8.74767
# 50%      8.74767
# 75%      8.74767
# max      8.74767
# Name: price, dtype: float64
# Category: chevrolet vega 2300
# count    1.000000
# mean     8.791182
# std           NaN
# min      8.791182
# 25%      8.791182
# 50%      8.791182
# 75%      8.791182
# max      8.791182
# Name: price, dtype: float64
# Category: dodge rampage
# count    1.000000
# mean     8.625689
# std           NaN
# min      8.625689
# 25%      8.625689
# 50%      8.625689
# 75%      8.625689
# max      8.625689
# Name: price, dtype: float64
# Category: dodge challenger se
# count    1.00000
# mean     8.76061
# std          NaN
# min      8.76061
# 25%      8.76061
# 50%      8.76061
# 75%      8.76061
# max      8.76061
# Name: price, dtype: float64
# Category: dodge d200
# count    1.000000
# mean     8.981933
# std           NaN
# min      8.981933
# 25%      8.981933
# 50%      8.981933
# 75%      8.981933
# max      8.981933
# Name: price, dtype: float64
# Category: dodge monaco (sw)
# count    1.000000
# mean     8.737132
# std           NaN
# min      8.737132
# 25%      8.737132
# 50%      8.737132
# 75%      8.737132
# max      8.737132
# Name: price, dtype: float64
# Category: dodge colt hardtop
# count    1.000000
# mean     8.808817
# std           NaN
# min      8.808817
# 25%      8.808817
# 50%      8.808817
# 75%      8.808817
# max      8.808817
# Name: price, dtype: float64
# Category: dodge colt (sw)
# count    1.000000
# mean     8.937218
# std           NaN
# min      8.937218
# 25%      8.937218
# 50%      8.937218
# 75%      8.937218
# max      8.937218
# Name: price, dtype: float64
# Category: dodge coronet custom
# count    1.000000
# mean     9.054739
# std           NaN
# min      9.054739
# 25%      9.054739
# 50%      9.054739
# 75%      9.054739
# max      9.054739
# Name: price, dtype: float64
# Category: dodge dart custom
# count    1.000000
# mean     9.096275
# std           NaN
# min      9.096275
# 25%      9.096275
# 50%      9.096275
# 75%      9.096275
# max      9.096275
# Name: price, dtype: float64
# Category: dodge coronet custom (sw)
# count    1.000000
# mean     9.470009
# std           NaN
# min      9.470009
# 25%      9.470009
# 50%      9.470009
# 75%      9.470009
# max      9.470009
# Name: price, dtype: float64
# Category: honda civic
# count    3.000000
# mean     9.116635
# std      0.461476
# min      8.594154
# 25%      8.940682
# 50%      9.287209
# 75%      9.377875
# max      9.468542
# Name: price, dtype: float64
# Category: honda civic cvcc
# count    2.000000
# mean     9.287209
# std      0.000000
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: honda accord cvcc
# count    1.000000
# mean     8.784162
# std           NaN
# min      8.784162
# 25%      8.784162
# 50%      8.784162
# 75%      8.784162
# max      8.784162
# Name: price, dtype: float64
# Category: honda accord lx
# count    1.000000
# mean     8.895082
# std           NaN
# min      8.895082
# 25%      8.895082
# 50%      8.895082
# 75%      8.895082
# max      8.895082
# Name: price, dtype: float64
# Category: honda civic 1500 gl
# count    1.000000
# mean     8.895082
# std           NaN
# min      8.895082
# 25%      8.895082
# 50%      8.895082
# 75%      8.895082
# max      8.895082
# Name: price, dtype: float64
# Category: honda accord
# count    2.000000
# mean     9.263360
# std      0.033728
# min      9.239511
# 25%      9.251435
# 50%      9.263360
# 75%      9.275284
# max      9.287209
# Name: price, dtype: float64
# Category: honda civic 1300
# count    1.00000
# mean     9.11559
# std          NaN
# min      9.11559
# 25%      9.11559
# 50%      9.11559
# 75%      9.11559
# max      9.11559
# Name: price, dtype: float64
# Category: honda prelude
# count    1.000000
# mean     9.087721
# std           NaN
# min      9.087721
# 25%      9.087721
# 50%      9.087721
# 75%      9.087721
# max      9.087721
# Name: price, dtype: float64
# Category: honda civic (auto)
# count    1.000000
# mean     9.244355
# std           NaN
# min      9.244355
# 25%      9.244355
# 50%      9.244355
# 75%      9.244355
# max      9.244355
# Name: price, dtype: float64
# Category: isuzu MU-X
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: isuzu D-Max
# count    2.000000
# mean     9.191490
# std      0.135367
# min      9.095771
# 25%      9.143630
# 50%      9.191490
# 75%      9.239349
# max      9.287209
# Name: price, dtype: float64
# Category: isuzu D-Max V-Cross
# count    1.000000
# mean     9.095771
# std           NaN
# min      9.095771
# 25%      9.095771
# 50%      9.095771
# 75%      9.095771
# max      9.095771
# Name: price, dtype: float64
# Category: jaguar xj
# count     1.000000
# mean     10.381304
# std            NaN
# min      10.381304
# 25%      10.381304
# 50%      10.381304
# 75%      10.381304
# max      10.381304
# Name: price, dtype: float64
# Category: jaguar xf
# count     1.000000
# mean     10.478724
# std            NaN
# min      10.478724
# 25%      10.478724
# 50%      10.478724
# 75%      10.478724
# max      10.478724
# Name: price, dtype: float64
# Category: jaguar xk
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: maxda rx3
# count    1.000000
# mean     8.555644
# std           NaN
# min      8.555644
# 25%      8.555644
# 50%      8.555644
# 75%      8.555644
# max      8.555644
# Name: price, dtype: float64
# Category: maxda glc deluxe
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: mazda rx2 coupe
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: mazda rx-4
# count    2.000000
# mean     9.260926
# std      0.037170
# min      9.234643
# 25%      9.247784
# 50%      9.260926
# 75%      9.274067
# max      9.287209
# Name: price, dtype: float64
# Category: mazda glc deluxe
# count    2.000000
# mean     9.097952
# std      0.267650
# min      8.908695
# 25%      9.003323
# 50%      9.097952
# 75%      9.192580
# max      9.287209
# Name: price, dtype: float64
# Category: mazda 626
# count    3.000000
# mean     9.234232
# std      0.128493
# min      9.087721
# 25%      9.187465
# 50%      9.287209
# 75%      9.307488
# max      9.327768
# Name: price, dtype: float64
# Category: mazda glc
# count    2.000000
# mean     9.333477
# std      0.065433
# min      9.287209
# 25%      9.310343
# 50%      9.333477
# 75%      9.356611
# max      9.379746
# Name: price, dtype: float64
# Category: mazda rx-7 gs
# count    2.000000
# mean     9.669157
# std      0.209240
# min      9.521202
# 25%      9.595179
# 50%      9.669157
# 75%      9.743135
# max      9.817112
# Name: price, dtype: float64
# Category: mazda glc 4
# count    1.000000
# mean     9.657971
# std           NaN
# min      9.657971
# 25%      9.657971
# 50%      9.657971
# 75%      9.657971
# max      9.657971
# Name: price, dtype: float64
# Category: mazda glc custom l
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: mazda glc custom
# count    1.000000
# mean     9.268232
# std           NaN
# min      9.268232
# 25%      9.268232
# 50%      9.268232
# 75%      9.268232
# max      9.268232
# Name: price, dtype: float64
# Category: buick electra 225 custom
# count     1.00000
# mean     10.14851
# std           NaN
# min      10.14851
# 25%      10.14851
# 50%      10.14851
# 75%      10.14851
# max      10.14851
# Name: price, dtype: float64
# Category: buick century luxus (sw)
# count     1.000000
# mean     10.248813
# std            NaN
# min      10.248813
# 25%      10.248813
# 50%      10.248813
# 75%      10.248813
# max      10.248813
# Name: price, dtype: float64
# Category: buick century
# count     1.000000
# mean     10.246261
# std            NaN
# min      10.246261
# 25%      10.246261
# 50%      10.246261
# 75%      10.246261
# max      10.246261
# Name: price, dtype: float64
# Category: buick skyhawk
# count     1.000000
# mean     10.360944
# std            NaN
# min      10.360944
# 25%      10.360944
# 50%      10.360944
# 75%      10.360944
# max      10.360944
# Name: price, dtype: float64
# Category: buick opel isuzu deluxe
# count     1.000000
# mean     10.439542
# std            NaN
# min      10.439542
# 25%      10.439542
# 50%      10.439542
# 75%      10.439542
# max      10.439542
# Name: price, dtype: float64
# Category: buick skylark
# count     1.000000
# mean     10.464731
# std            NaN
# min      10.464731
# 25%      10.464731
# 50%      10.464731
# 75%      10.464731
# max      10.464731
# Name: price, dtype: float64
# Category: buick century special
# count     1.000000
# mean     10.620376
# std            NaN
# min      10.620376
# 25%      10.620376
# 50%      10.620376
# 75%      10.620376
# max      10.620376
# Name: price, dtype: float64
# Category: buick regal sport coupe (turbo)
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: mercury cougar
# count    1.000000
# mean     9.711358
# std           NaN
# min      9.711358
# 25%      9.711358
# 50%      9.711358
# 75%      9.711358
# max      9.711358
# Name: price, dtype: float64
# Category: mitsubishi mirage
# count    1.000000
# mean     8.592301
# std           NaN
# min      8.592301
# 25%      8.592301
# 50%      8.592301
# 75%      8.592301
# max      8.592301
# Name: price, dtype: float64
# Category: mitsubishi lancer
# count    1.00000
# mean     8.73069
# std          NaN
# min      8.73069
# 25%      8.73069
# 50%      8.73069
# 75%      8.73069
# max      8.73069
# Name: price, dtype: float64
# Category: mitsubishi outlander
# count    3.000000
# mean     9.128274
# std      0.319291
# min      8.805375
# 25%      8.970496
# 50%      9.135617
# 75%      9.289724
# max      9.443830
# Name: price, dtype: float64
# Category: mitsubishi g4
# count    3.000000
# mean     9.200866
# std      0.355355
# min      8.947676
# 25%      8.997749
# 50%      9.047821
# 75%      9.327461
# max      9.607101
# Name: price, dtype: float64
# Category: mitsubishi mirage g4
# count    3.000000
# mean     9.307721
# std      0.239476
# min      9.135617
# 25%      9.170975
# 50%      9.206332
# 75%      9.393773
# max      9.581214
# Name: price, dtype: float64
# Category: mitsubishi montero
# count    1.000000
# mean     8.852236
# std           NaN
# min      8.852236
# 25%      8.852236
# 50%      8.852236
# 75%      8.852236
# max      8.852236
# Name: price, dtype: float64
# Category: mitsubishi pajero
# count    1.000000
# mean     9.010669
# std           NaN
# min      9.010669
# 25%      9.010669
# 50%      9.010669
# 75%      9.010669
# max      9.010669
# Name: price, dtype: float64
# Category: Nissan versa
# count    1.000000
# mean     8.612503
# std           NaN
# min      8.612503
# 25%      8.612503
# 50%      8.612503
# 75%      8.612503
# max      8.612503
# Name: price, dtype: float64
# Category: nissan gt-r
# count    1.00000
# mean     8.86785
# std          NaN
# min      8.86785
# 25%      8.86785
# 50%      8.86785
# 75%      8.86785
# max      8.86785
# Name: price, dtype: float64
# Category: nissan rogue
# count    2.000000
# mean     9.193309
# std      0.132795
# min      9.099409
# 25%      9.146359
# 50%      9.193309
# 75%      9.240259
# max      9.287209
# Name: price, dtype: float64
# Category: nissan latio
# count    2.000000
# mean     8.877331
# std      0.064102
# min      8.832004
# 25%      8.854668
# 50%      8.877331
# 75%      8.899995
# max      8.922658
# Name: price, dtype: float64
# Category: nissan titan
# count    1.000000
# mean     8.902456
# std           NaN
# min      8.902456
# 25%      8.902456
# 50%      8.902456
# 75%      8.902456
# max      8.902456
# Name: price, dtype: float64
# Category: nissan leaf
# count    1.00000
# mean     8.89563
# std          NaN
# min      8.89563
# 25%      8.89563
# 50%      8.89563
# 75%      8.89563
# max      8.89563
# Name: price, dtype: float64
# Category: nissan juke
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: nissan note
# count    1.000000
# mean     8.987197
# std           NaN
# min      8.987197
# 25%      8.987197
# 50%      8.987197
# 75%      8.987197
# max      8.987197
# Name: price, dtype: float64
# Category: nissan clipper
# count    2.000000
# mean     9.287209
# std      0.000000
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: nissan nv200
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: nissan dayz
# count    1.000000
# mean     9.510445
# std           NaN
# min      9.510445
# 25%      9.510445
# 50%      9.510445
# 75%      9.510445
# max      9.510445
# Name: price, dtype: float64
# Category: nissan fuga
# count    1.000000
# mean     9.574983
# std           NaN
# min      9.574983
# 25%      9.574983
# 50%      9.574983
# 75%      9.574983
# max      9.574983
# Name: price, dtype: float64
# Category: nissan otti
# count    1.000000
# mean     9.510445
# std           NaN
# min      9.510445
# 25%      9.510445
# 50%      9.510445
# 75%      9.510445
# max      9.510445
# Name: price, dtype: float64
# Category: nissan teana
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: nissan kicks
# count    1.000000
# mean     9.888374
# std           NaN
# min      9.888374
# 25%      9.888374
# 50%      9.888374
# 75%      9.888374
# max      9.888374
# Name: price, dtype: float64
# Category: peugeot 504
# count    6.000000
# mean     9.619200
# std      0.184375
# min      9.287209
# 25%      9.566078
# 50%      9.686416
# 75%      9.721949
# max      9.795401
# Name: price, dtype: float64
# Category: peugeot 304
# count    1.000000
# mean     9.488048
# std           NaN
# min      9.488048
# 25%      9.488048
# 50%      9.488048
# 75%      9.488048
# max      9.488048
# Name: price, dtype: float64
# Category: peugeot 504 (sw)
# count    1.000000
# mean     9.428753
# std           NaN
# min      9.428753
# 25%      9.428753
# 50%      9.428753
# 75%      9.428753
# max      9.428753
# Name: price, dtype: float64
# Category: peugeot 604sl
# count    2.000000
# mean     9.770805
# std      0.050454
# min      9.735128
# 25%      9.752966
# 50%      9.770805
# 75%      9.788643
# max      9.806481
# Name: price, dtype: float64
# Category: peugeot 505s turbo diesel
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: plymouth fury iii
# count    2.000000
# mean     8.956449
# std      0.467765
# min      8.625689
# 25%      8.791069
# 50%      8.956449
# 75%      9.121829
# max      9.287209
# Name: price, dtype: float64
# Category: plymouth cricket
# count    1.000000
# mean     8.981933
# std           NaN
# min      8.981933
# 25%      8.981933
# 50%      8.981933
# 75%      8.981933
# max      8.981933
# Name: price, dtype: float64
# Category: plymouth satellite custom (sw)
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: plymouth fury gran sedan
# count    1.000000
# mean     8.937218
# std           NaN
# min      8.937218
# 25%      8.937218
# 50%      8.937218
# 75%      8.937218
# max      8.937218
# Name: price, dtype: float64
# Category: plymouth valiant
# count    1.000000
# mean     9.096275
# std           NaN
# min      9.096275
# 25%      9.096275
# 50%      9.096275
# 75%      9.096275
# max      9.096275
# Name: price, dtype: float64
# Category: plymouth duster
# count    1.000000
# mean     9.454462
# std           NaN
# min      9.454462
# 25%      9.454462
# 50%      9.454462
# 75%      9.454462
# max      9.454462
# Name: price, dtype: float64
# Category: porsche macan
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: porcshce panamera
# count     1.000000
# mean     10.389887
# std            NaN
# min      10.389887
# 25%      10.389887
# 50%      10.389887
# 75%      10.389887
# max      10.389887
# Name: price, dtype: float64
# Category: porsche cayenne
# count     2.000000
# mean     10.394790
# std       0.056821
# min      10.354611
# 25%      10.374700
# 50%      10.394790
# 75%      10.414879
# max      10.434968
# Name: price, dtype: float64
# Category: porsche boxter
# count     1.000000
# mean     10.519457
# std            NaN
# min      10.519457
# 25%      10.519457
# 50%      10.519457
# 75%      10.519457
# max      10.519457
# Name: price, dtype: float64
# Category: renault 12tl
# count    1.000000
# mean     9.137339
# std           NaN
# min      9.137339
# 25%      9.137339
# 50%      9.137339
# 75%      9.137339
# max      9.137339
# Name: price, dtype: float64
# Category: renault 5 gtl
# count    1.000000
# mean     9.199886
# std           NaN
# min      9.199886
# 25%      9.199886
# 50%      9.199886
# 75%      9.199886
# max      9.199886
# Name: price, dtype: float64
# Category: saab 99e
# count    2.000000
# mean     9.606106
# std      0.319526
# min      9.380168
# 25%      9.493137
# 50%      9.606106
# 75%      9.719076
# max      9.832045
# Name: price, dtype: float64
# Category: saab 99le
# count    2.000000
# mean     9.512673
# std      0.149711
# min      9.406811
# 25%      9.459742
# 50%      9.512673
# 75%      9.565604
# max      9.618535
# Name: price, dtype: float64
# Category: saab 99gle
# count    2.000000
# mean     9.546845
# std      0.367181
# min      9.287209
# 25%      9.417027
# 50%      9.546845
# 75%      9.676663
# max      9.806481
# Name: price, dtype: float64
# Category: subaru
# count    2.000000
# mean     8.706180
# std      0.234004
# min      8.540714
# 25%      8.623447
# 50%      8.706180
# 75%      8.788913
# max      8.871646
# Name: price, dtype: float64
# Category: subaru dl
# count    4.000000
# mean     9.112976
# std      0.251215
# min      8.861350
# 25%      8.917660
# 50%      9.111819
# 75%      9.307136
# max      9.366917
# Name: price, dtype: float64
# Category: subaru brz
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: subaru baja
# count    1.000000
# mean     9.206433
# std           NaN
# min      9.206433
# 25%      9.206433
# 50%      9.206433
# 75%      9.206433
# max      9.206433
# Name: price, dtype: float64
# Category: subaru r1
# count    1.000000
# mean     9.130648
# std           NaN
# min      9.130648
# 25%      9.130648
# 50%      9.130648
# 75%      9.130648
# max      9.130648
# Name: price, dtype: float64
# Category: subaru r2
# count    1.000000
# mean     9.329012
# std           NaN
# min      9.329012
# 25%      9.329012
# 50%      9.329012
# 75%      9.329012
# max      9.329012
# Name: price, dtype: float64
# Category: subaru trezia
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: subaru tribeca
# count    1.000000
# mean     9.230045
# std           NaN
# min      9.230045
# 25%      9.230045
# 50%      9.230045
# 75%      9.230045
# max      9.230045
# Name: price, dtype: float64
# Category: toyota corona mark ii
# count    1.000000
# mean     8.584665
# std           NaN
# min      8.584665
# 25%      8.584665
# 50%      8.584665
# 75%      8.584665
# max      8.584665
# Name: price, dtype: float64
# Category: toyota corona
# count    6.000000
# mean     9.153722
# std      0.318898
# min      8.754476
# 25%      8.985027
# 50%      9.112937
# 75%      9.267717
# max      9.680281
# Name: price, dtype: float64
# Category: toyota corolla 1200
# count    2.000000
# mean     9.032536
# std      0.360161
# min      8.777864
# 25%      8.905200
# 50%      9.032536
# 75%      9.159873
# max      9.287209
# Name: price, dtype: float64
# Category: toyota corona hardtop
# count    1.000000
# mean     8.842027
# std           NaN
# min      8.842027
# 25%      8.842027
# 50%      8.842027
# 75%      8.842027
# max      8.842027
# Name: price, dtype: float64
# Category: toyota corolla 1600 (sw)
# count    1.000000
# mean     8.974491
# std           NaN
# min      8.974491
# 25%      8.974491
# 50%      8.974491
# 75%      8.974491
# max      8.974491
# Name: price, dtype: float64
# Category: toyota carina
# count    1.000000
# mean     9.080118
# std           NaN
# min      9.080118
# 25%      9.080118
# 50%      9.080118
# 75%      9.080118
# max      9.080118
# Name: price, dtype: float64
# Category: toyota mark ii
# count    3.000000
# mean     9.102100
# std      0.243072
# min      8.844913
# 25%      8.989132
# 50%      9.133351
# 75%      9.230693
# max      9.328035
# Name: price, dtype: float64
# Category: toyota corolla
# count    6.000000
# mean     9.183886
# std      0.158616
# min      8.960468
# 25%      9.066740
# 50%      9.230443
# 75%      9.294122
# max      9.354441
# Name: price, dtype: float64
# Category: toyota corolla liftback
# count    2.000000
# mean     9.500947
# std      0.302271
# min      9.287209
# 25%      9.394078
# 50%      9.500947
# 75%      9.607816
# max      9.714685
# Name: price, dtype: float64
# Category: toyota celica gt liftback
# count    1.000000
# mean     9.137662
# std           NaN
# min      9.137662
# 25%      9.137662
# 50%      9.137662
# 75%      9.137662
# max      9.137662
# Name: price, dtype: float64
# Category: toyota corolla tercel
# count    1.000000
# mean     9.163144
# std           NaN
# min      9.163144
# 25%      9.163144
# 50%      9.163144
# 75%      9.163144
# max      9.163144
# Name: price, dtype: float64
# Category: toyota corona liftback
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: toyota starlet
# count    2.000000
# mean     9.435091
# std      0.319261
# min      9.209340
# 25%      9.322216
# 50%      9.435091
# 75%      9.547967
# max      9.660843
# Name: price, dtype: float64
# Category: toyota tercel
# count    1.000000
# mean     9.323669
# std           NaN
# min      9.323669
# 25%      9.323669
# 50%      9.323669
# 75%      9.323669
# max      9.323669
# Name: price, dtype: float64
# Category: toyota cressida
# count    1.000000
# mean     9.779624
# std           NaN
# min      9.779624
# 25%      9.779624
# 50%      9.779624
# 75%      9.779624
# max      9.779624
# Name: price, dtype: float64
# Category: toyota celica gt
# count    1.000000
# mean     9.277906
# std           NaN
# min      9.277906
# 25%      9.277906
# 50%      9.277906
# 75%      9.277906
# max      9.277906
# Name: price, dtype: float64
# Category: toyouta tercel
# count    1.000000
# mean     9.664659
# std           NaN
# min      9.664659
# 25%      9.664659
# 50%      9.664659
# 75%      9.664659
# max      9.664659
# Name: price, dtype: float64
# Category: vokswagen rabbit
# count    1.000000
# mean     8.958797
# std           NaN
# min      8.958797
# 25%      8.958797
# 50%      8.958797
# 75%      8.958797
# max      8.958797
# Name: price, dtype: float64
# Category: volkswagen 1131 deluxe sedan
# count    1.000000
# mean     8.984192
# std           NaN
# min      8.984192
# 25%      8.984192
# 50%      8.984192
# 75%      8.984192
# max      8.984192
# Name: price, dtype: float64
# Category: volkswagen model 111
# count    1.000000
# mean     8.986697
# std           NaN
# min      8.986697
# 25%      8.986697
# 50%      8.986697
# 75%      8.986697
# max      8.986697
# Name: price, dtype: float64
# Category: volkswagen type 3
# count    1.000000
# mean     9.011402
# std           NaN
# min      9.011402
# 25%      9.011402
# 50%      9.011402
# 75%      9.011402
# max      9.011402
# Name: price, dtype: float64
# Category: volkswagen 411 (sw)
# count    1.000000
# mean     9.047351
# std           NaN
# min      9.047351
# 25%      9.047351
# 50%      9.047351
# 75%      9.047351
# max      9.047351
# Name: price, dtype: float64
# Category: volkswagen super beetle
# count    1.000000
# mean     9.158626
# std           NaN
# min      9.158626
# 25%      9.158626
# 50%      9.158626
# 75%      9.158626
# max      9.158626
# Name: price, dtype: float64
# Category: volkswagen dasher
# count    2.000000
# mean     9.313281
# std      0.146146
# min      9.209940
# 25%      9.261611
# 50%      9.313281
# 75%      9.364952
# max      9.416623
# Name: price, dtype: float64
# Category: vw dasher
# count    1.000000
# mean     9.358415
# std           NaN
# min      9.358415
# 25%      9.358415
# 50%      9.358415
# 75%      9.358415
# max      9.358415
# Name: price, dtype: float64
# Category: vw rabbit
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: volkswagen rabbit
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: volkswagen rabbit custom
# count    1.000000
# mean     9.535752
# std           NaN
# min      9.535752
# 25%      9.535752
# 50%      9.535752
# 75%      9.535752
# max      9.535752
# Name: price, dtype: float64
# Category: volvo 145e (sw)
# count    2.000000
# mean     9.377682
# std      0.127949
# min      9.287209
# 25%      9.332446
# 50%      9.377682
# 75%      9.422919
# max      9.468156
# Name: price, dtype: float64
# Category: volvo 144ea
# count    2.000000
# mean     9.679408
# std      0.247777
# min      9.504203
# 25%      9.591806
# 50%      9.679408
# 75%      9.767010
# max      9.854612
# Name: price, dtype: float64
# Category: volvo 244dl
# count    2.000000
# mean     9.631183
# std      0.486453
# min      9.287209
# 25%      9.459196
# 50%      9.631183
# 75%      9.803170
# max      9.975157
# Name: price, dtype: float64
# Category: volvo 245
# count    1.000000
# mean     9.712085
# std           NaN
# min      9.712085
# 25%      9.712085
# 50%      9.712085
# 75%      9.712085
# max      9.712085
# Name: price, dtype: float64
# Category: volvo 264gl
# count     2.000000
# mean      9.657032
# std       0.523009
# min       9.287209
# 25%       9.472120
# 50%       9.657032
# 75%       9.841943
# max      10.026855
# Name: price, dtype: float64
# Category: volvo diesel
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: volvo 246
# count     1.000000
# mean     10.019981
# std            NaN
# min      10.019981
# 25%      10.019981
# 50%      10.019981
# 75%      10.019981
# max      10.019981
# Name: price, dtype: float64
#
#
# Impact of fueltype on 'price':
# Category: gas
# count    191.000000
# mean       9.337526
# std        0.441184
# min        8.540714
# 25%        9.067428
# 50%        9.287209
# 75%        9.539529
# max       10.629005
# Name: price, dtype: float64
# Category: diesel
# count    14.000000
# mean      9.640715
# std       0.541325
# min       8.867850
# 25%       9.061825
# 50%       9.765265
# 75%      10.116378
# max      10.360944
# Name: price, dtype: float64
#
#
# Impact of aspiration on 'price':
# Category: std
# count    168.000000
# mean       9.307534
# std        0.452817
# min        8.540714
# 25%        9.004801
# 50%        9.287209
# 75%        9.505690
# max       10.629005
# Name: price, dtype: float64
# Category: turbo
# count    37.000000
# mean      9.588426
# std       0.385723
# min       8.947676
# 25%       9.287209
# 50%       9.536834
# 75%       9.832045
# max      10.360944
# Name: price, dtype: float64
#
#
# Impact of doornumber on 'price':
# Category: two
# count    90.000000
# mean      9.305985
# std       0.476795
# min       8.540714
# 25%       8.982498
# 50%       9.287209
# 75%       9.566211
# max      10.629005
# Name: price, dtype: float64
# Category: four
# count    115.000000
# mean       9.399120
# std        0.432457
# min        8.737132
# 25%        9.096275
# 50%        9.287209
# 75%        9.662751
# max       10.620376
# Name: price, dtype: float64
#
#
# Impact of carbody on 'price':
# Category: convertible
# count     6.000000
# mean      9.890592
# std       0.489399
# min       9.358415
# 25%       9.560406
# 50%       9.745400
# 75%      10.293454
# max      10.519457
# Name: price, dtype: float64
# Category: hatchback
# count    70.000000
# mean      9.188259
# std       0.378280
# min       8.540714
# 25%       8.939241
# 50%       9.287209
# 75%       9.373419
# max      10.354611
# Name: price, dtype: float64
# Category: sedan
# count    96.000000
# mean      9.427820
# std       0.469062
# min       8.612503
# 25%       9.095771
# 50%       9.287209
# 75%       9.735498
# max      10.629005
# Name: price, dtype: float64
# Category: wagon
# count    25.000000
# mean      9.336599
# std       0.338853
# min       8.842027
# 25%       9.096275
# 50%       9.287209
# 75%       9.536834
# max      10.248813
# Name: price, dtype: float64
# Category: hardtop
# count     8.000000
# mean      9.678761
# std       0.565780
# min       9.173676
# 25%       9.287209
# 50%       9.305439
# 75%      10.282168
# max      10.434968
# Name: price, dtype: float64
#
#
# Impact of drivewheel on 'price':
# Category: rwd
# count    76.000000
# mean      9.718406
# std       0.435356
# min       9.016634
# 25%       9.287209
# 50%       9.693603
# 75%       9.986363
# max      10.629005
# Name: price, dtype: float64
# Category: fwd
# count    120.000000
# mean       9.134803
# std        0.305576
# min        8.540714
# 25%        8.907135
# 50%        9.136478
# 75%        9.287209
# max       10.080629
# Name: price, dtype: float64
# Category: 4wd
# count    9.000000
# mean     9.295812
# std      0.312079
# min      8.936430
# 25%      9.080118
# 50%      9.287209
# 75%      9.366917
# max      9.790328
# Name: price, dtype: float64
#
#
# Impact of enginelocation on 'price':
# Category: front
# count    202.000000
# mean       9.342045
# std        0.436891
# min        8.540714
# 25%        9.049551
# 50%        9.287209
# 75%        9.579656
# max       10.629005
# Name: price, dtype: float64
# Category: rear
# count     3.000000
# mean     10.448104
# std       0.065776
# min      10.389887
# 25%      10.412428
# 50%      10.434968
# 75%      10.477213
# max      10.519457
# Name: price, dtype: float64
#
#
# Impact of enginetype on 'price':
# Category: dohc
# count    12.000000
# mean      9.728429
# std       0.396995
# min       9.137662
# 25%       9.623169
# 50%       9.695729
# 75%       9.812872
# max      10.478724
# Name: price, dtype: float64
# Category: ohcv
# count    13.000000
# mean      9.757236
# std       0.484479
# min       9.287209
# 25%       9.287209
# 50%       9.574983
# 75%       9.975157
# max      10.620376
# Name: price, dtype: float64
# Category: ohc
# count    148.000000
# mean       9.270030
# std        0.411109
# min        8.555644
# 25%        8.983627
# 50%        9.287209
# 75%        9.409264
# max       10.629005
# Name: price, dtype: float64
# Category: l
# count    12.000000
# mean      9.500663
# std       0.351991
# min       8.547140
# 25%       9.393367
# 50%       9.595321
# 75%       9.725975
# max       9.806481
# Name: price, dtype: float64
# Category: rotor
# count    4.000000
# mean     9.461532
# std      0.162508
# min      9.287209
# 25%      9.356611
# 50%      9.450474
# 75%      9.555394
# max      9.657971
# Name: price, dtype: float64
# Category: ohcf
# count    15.000000
# mean      9.378609
# std       0.597801
# min       8.540714
# 25%       9.033539
# 50%       9.287209
# 75%       9.347964
# max      10.519457
# Name: price, dtype: float64
# Category: dohcv
# count     1.000000
# mean     10.354611
# std            NaN
# min      10.354611
# 25%      10.354611
# 50%      10.354611
# 75%      10.354611
# max      10.354611
# Name: price, dtype: float64
#
#
# Impact of cylindernumber on 'price':
# Category: four
# count    159.000000
# mean       9.202596
# std        0.307962
# min        8.540714
# 25%        8.981933
# 50%        9.268232
# 75%        9.327901
# max       10.026855
# Name: price, dtype: float64
# Category: six
# count    24.000000
# mean      9.966066
# std       0.413423
# min       9.287209
# 25%       9.663705
# 50%       9.954104
# 75%      10.383450
# max      10.629005
# Name: price, dtype: float64
# Category: five
# count    11.000000
# mean      9.926565
# std       0.321574
# min       9.287209
# 25%       9.774547
# 50%       9.848028
# 75%      10.197386
# max      10.360944
# Name: price, dtype: float64
# Category: three
# count    1.00000
# mean     8.54714
# std          NaN
# min      8.54714
# 25%      8.54714
# 50%      8.54714
# 75%      8.54714
# max      8.54714
# Name: price, dtype: float64
# Category: twelve
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: two
# count    4.000000
# mean     9.461532
# std      0.162508
# min      9.287209
# 25%      9.356611
# 50%      9.450474
# 75%      9.555394
# max      9.657971
# Name: price, dtype: float64
# Category: eight
# count     5.000000
# mean     10.233294
# std       0.537524
# min       9.287209
# 25%      10.354611
# 50%      10.439542
# 75%      10.464731
# max      10.620376
# Name: price, dtype: float64
#
#
# Impact of fuelsystem on 'price':
# Category: mpfi
# count    94.000000
# mean      9.611305
# std       0.420152
# min       8.981933
# 25%       9.287209
# 50%       9.510445
# 75%       9.802443
# max      10.629005
# Name: price, dtype: float64
# Category: 2bbl
# count    66.000000
# mean      9.001264
# std       0.243399
# min       8.540714
# 25%       8.814614
# 50%       9.013652
# 75%       9.287209
# max       9.327768
# Name: price, dtype: float64
# Category: mfi
# count    1.000000
# mean     9.470009
# std           NaN
# min      9.470009
# 25%      9.470009
# 50%      9.470009
# 75%      9.470009
# max      9.470009
# Name: price, dtype: float64
# Category: 1bbl
# count    11.000000
# mean      9.069103
# std       0.242727
# min       8.594154
# 25%       8.895082
# 50%       9.115590
# 75%       9.287209
# max       9.287209
# Name: price, dtype: float64
# Category: spfi
# count    1.000000
# mean     9.287209
# std           NaN
# min      9.287209
# 25%      9.287209
# 50%      9.287209
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: 4bbl
# count    3.000000
# mean     9.396052
# std      0.117846
# min      9.287209
# 25%      9.333477
# 50%      9.379746
# 75%      9.450474
# max      9.521202
# Name: price, dtype: float64
# Category: idi
# count    20.000000
# mean      9.534602
# std       0.489436
# min       8.867850
# 25%       9.115644
# 50%       9.511900
# 75%       9.867829
# max      10.360944
# Name: price, dtype: float64
# Category: spdi
# count    9.000000
# mean     9.277087
# std      0.250332
# min      8.947676
# 25%      9.135617
# 50%      9.206332
# 75%      9.454462
# max      9.607101
# Name: price, dtype: float64
#
#
# Impact of car_company on 'price':
# Category: alfa-romero
# count    3.000000
# mean     9.644167
# std      0.116063
# min      9.510149
# 25%      9.610662
# 50%      9.711176
# 75%      9.711176
# max      9.711176
# Name: price, dtype: float64
# Category: audi
# count     7.000000
# mean      9.777684
# std       0.169830
# min       9.543306
# 25%       9.699776
# 50%       9.781941
# 75%       9.819178
# max      10.080629
# Name: price, dtype: float64
# Category: bmw
# count     8.000000
# mean     10.117415
# std       0.345174
# min       9.706925
# 25%       9.897323
# 50%      10.033216
# 75%      10.379365
# max      10.629005
# Name: price, dtype: float64
# Category: chevrolet
# count    3.000000
# mean     8.695331
# std      0.130168
# min      8.547140
# 25%      8.647405
# 50%      8.747670
# 75%      8.769426
# max      8.791182
# Name: price, dtype: float64
# Category: dodge
# count    9.000000
# mean     8.941380
# std      0.252384
# min      8.625689
# 25%      8.760610
# 50%      8.937218
# 75%      9.054739
# max      9.470009
# Name: price, dtype: float64
# Category: honda
# count    13.000000
# mean      9.113310
# std       0.250669
# min       8.594154
# 25%       8.895082
# 50%       9.239511
# 75%       9.287209
# max       9.468542
# Name: price, dtype: float64
# Category: isuzu
# count    4.000000
# mean     9.191490
# std      0.110527
# min      9.095771
# 25%      9.095771
# 50%      9.191490
# 75%      9.287209
# max      9.287209
# Name: price, dtype: float64
# Category: jaguar
# count     3.000000
# mean     10.049079
# std       0.661594
# min       9.287209
# 25%       9.834257
# 50%      10.381304
# 75%      10.430014
# max      10.478724
# Name: price, dtype: float64
# Category: mazda
# count    17.000000
# mean      9.280541
# std       0.274300
# min       8.555644
# 25%       9.268232
# 50%       9.287209
# 75%       9.327768
# max       9.817112
# Name: price, dtype: float64
# Category: buick
# count     8.000000
# mean     10.227048
# std       0.407885
# min       9.287209
# 25%      10.221823
# 50%      10.304879
# 75%      10.445839
# max      10.620376
# Name: price, dtype: float64
# Category: mercury
# count    1.000000
# mean     9.711358
# std           NaN
# min      9.711358
# 25%      9.711358
# 50%      9.711358
# 75%      9.711358
# max      9.711358
# Name: price, dtype: float64
# Category: mitsubishi
# count    13.000000
# mean      9.084345
# std       0.315415
# min       8.592301
# 25%       8.852236
# 50%       9.047821
# 75%       9.206332
# max       9.607101
# Name: price, dtype: float64
# Category: Nissan
# count    1.000000
# mean     8.612503
# std           NaN
# min      8.612503
# 25%      8.612503
# 50%      8.612503
# 75%      8.612503
# max      8.612503
# Name: price, dtype: float64
# Category: nissan
# count    17.000000
# mean      9.218512
# std       0.296466
# min       8.832004
# 25%       8.922658
# 50%       9.287209
# 75%       9.287209
# max       9.888374
# Name: price, dtype: float64
# Category: peugeot
# count    11.000000
# mean      9.587347
# std       0.192617
# min       9.287209
# 25%       9.458400
# 50%       9.653808
# 75%       9.729026
# max       9.806481
# Name: price, dtype: float64
# Category: plymouth
# count    7.000000
# mean     9.095714
# std      0.277198
# min      8.625689
# 25%      8.959576
# 50%      9.096275
# 75%      9.287209
# max      9.454462
# Name: price, dtype: float64
# Category: porsche
# count     5.000000
# mean     10.197226
# std       0.512439
# min       9.287209
# 25%      10.354611
# 50%      10.389887
# 75%      10.434968
# max      10.519457
# Name: price, dtype: float64
# Category: renault
# count    2.000000
# mean     9.168613
# std      0.044227
# min      9.137339
# 25%      9.152976
# 50%      9.168613
# 75%      9.184249
# max      9.199886
# Name: price, dtype: float64
# Category: saab
# count    6.000000
# mean     9.555208
# std      0.231634
# min      9.287209
# 25%      9.386828
# 50%      9.512673
# 75%      9.759494
# max      9.832045
# Name: price, dtype: float64
# Category: subaru
# count    12.000000
# mean      9.111235
# std       0.253189
# min       8.540714
# 25%       8.920234
# 50%       9.218239
# 75%       9.287209
# max       9.366917
# Name: price, dtype: float64
# Category: toyota
# count    32.000000
# mean      9.199508
# std       0.290964
# min       8.584665
# 25%       9.006099
# 50%       9.209290
# 75%       9.303237
# max       9.779624
# Name: price, dtype: float64
# Category: volkswagen
# count    12.000000
# mean      9.186851
# std       0.192783
# min       8.958797
# 25%       9.005225
# 50%       9.184283
# 75%       9.305010
# max       9.535752
# Name: price, dtype: float64
# Category: volvo
# count    11.000000
# mean      9.609989
# std       0.315204
# min       9.287209
# 25%       9.287209
# 50%       9.504203
# 75%       9.914885
# max      10.026855
# Name: price, dtype: float64
